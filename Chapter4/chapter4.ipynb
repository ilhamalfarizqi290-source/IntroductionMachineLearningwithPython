# %% [markdown]
# # Chapter 4 - Representing Data and Feature Engineering
#
# Pada chapter ini mempelajari bagaimana merepresentasikan data agar dapat digunakan oleh algoritma machine learning.
# Feature engineering adalah proses mengubah data mentah menjadi fitur yang lebih berguna untuk model.

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

data = pd.DataFrame({
    "City": ["Jakarta", "Bandung", "Surabaya", "Jakarta"]
})

encoder = OneHotEncoder(sparse=False)
encoded = encoder.fit_transform(data)

print(encoded)

# %% [markdown]
# ## Summary
#
# Pada chapter ini dipelajari:
#
# - Konsep feature engineering
# - Representasi data untuk machine learning
# - One Hot Encoding untuk data kategori
