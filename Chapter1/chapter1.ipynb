# %%
# Chapter 1 - Introduction to Machine Learning

Machine Learning adalah metode yang memungkinkan komputer belajar dari data tanpa diprogram secara eksplisit.
Pada notebook ini kita menggunakan dataset Iris dari sklearn.

# %%
from sklearn.datasets import load_iris

iris = load_iris()

print("Feature names:")
print(iris.feature_names)

print("\nTarget names:")
print(iris.target_names)
# Out:
# Feature names:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
#
# Target names:
# ['setosa' 'versicolor' 'virginica']
