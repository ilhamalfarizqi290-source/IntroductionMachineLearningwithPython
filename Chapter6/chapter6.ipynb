# %% [markdown]
# # Chapter 6 - Algorithm Chains and Pipelines
#
# Pipeline digunakan untuk menggabungkan beberapa langkah machine learning dalam satu proses.

# %%
from sklearn.datasets import load_iris
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier

iris = load_iris()

pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("knn", KNeighborsClassifier())
])

pipeline.fit(iris.data, iris.target)

print("Pipeline model trained successfully")

# %% [markdown]
# ## Summary
#
# Pada chapter ini dipelajari:
#
# - Konsep pipeline
# - Menggabungkan preprocessing dan model
# - Pipeline dalam sklearn
